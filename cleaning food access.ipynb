# %%
! pip install openpyxl
# !pip install --upgrade pip
import pandas as pd
import openpyxl
excel_file = 'FoodAccessResearchAtlasData2019 (1).xlsx'
df1 = pd.read_excel(excel_file, sheet_name='Read Me')
df2 = pd.read_excel(excel_file, sheet_name='Variable Lookup')
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 kB 18.2 MB/s eta 0:00:00
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 37.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 23.0.1
#     Uninstalling pip-23.0.1:
#       Successfully uninstalled pip-23.0.1
# ...

# %%
#food_access = df3[(df3['State'] == 'North Carolina') & (df3['County'] == 'Mecklenburg County')]
#food_access

# %%
#food_access['CensusTract'] = food_access['CensusTract'].astype(str)
#food_access['CensusTract'] = food_access['CensusTract'].str[-4:]  
#food_access['CensusTract'] = food_access['CensusTract'].str.lstrip('0').replace(r'^(\d{2})(\d+)$', r'\1.\2', regex=True)
#food_access

# %%
path='food_access - food_access.csv'
food_access=pd.read_csv(path)
food_access
# Out:
#      CensusTract           State              County  Urban  Pop2010  OHU2010  \
# 0           1.00  North Carolina  Mecklenburg County      1     3425     2025
# 1           3.00  North Carolina  Mecklenburg County      1      407      336
# 2           4.00  North Carolina  Mecklenburg County      1     1599     1173
# 3           5.00  North Carolina  Mecklenburg County      1     4964     2280
# 4           6.00  North Carolina  Mecklenburg County      1     4100     1568
# ..           ...             ...                 ...    ...      ...      ...
# 225        64.03  North Carolina  Mecklenburg County      1     5319     1461
# 226        64.04  North Carolina  Mecklenburg County      0     4952     1688
# 227        64.05  North Carolina  Mecklenburg County      1     3081     1385
# 228        64.06  North Carolina  Mecklenburg County      1     6132     2407
# 229        64.07  North Carolina  Mecklenburg County      1     3313     1185
#
# ...

# %%
df2
# Out:
#              Field                                           LongName  \
# 0      CensusTract                                       Census tract
# 1            State                                              State
# 2           County                                             County
# 3            Urban                                        Urban tract
# 4          POP2010                            Population, tract total
# ..             ...                                                ...
# 142      TractAIAN  Tract American Indian and Alaska Native popula...
# 143   TractOMultir       Tract Other/Multiple race population, number
# 144  TractHispanic        Tract Hispanic or Latino population, number
# 145      TractHUNV      Tract housing units without a vehicle, number
# 146      TractSNAP  Tract housing units receiving SNAP benefits, n...
#
#                                            Description
# 0                                  Census tract number
# ...

# %%
filtered = food_access[food_access['LILATracts_1And20']==1]
filtered
# Out:
#      CensusTract           State              County  Urban  Pop2010  OHU2010  \
# 19         16.03  North Carolina  Mecklenburg County      1     4598     1821
# 24         16.09  North Carolina  Mecklenburg County      1     3168     1239
# 74         32.01  North Carolina  Mecklenburg County      1     2785     1123
# 82         38.02  North Carolina  Mecklenburg County      1     3414     1353
# 93         43.03  North Carolina  Mecklenburg County      1     2557      905
# 94         43.04  North Carolina  Mecklenburg County      1     3466     1224
# 96         44.00  North Carolina  Mecklenburg County      1     4249     1455
# 97         45.00  North Carolina  Mecklenburg County      1     2957     1017
# 106        53.05  North Carolina  Mecklenburg County      1     5005     1717
# 110        54.01  North Carolina  Mecklenburg County      1     6853     2633
# 111        54.03  North Carolina  Mecklenburg County      1     4052     1472
# ...

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=92d3bad9-b1e6-4572-bf43-ff2358b72657' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
